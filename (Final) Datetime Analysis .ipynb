# %%
import pandas as pd
import datetime

# %%
df=pd.read_csv("crimechicago2.csv") #index_col='Date'
df.tail()
# Out:
#               ID Case Number            Date                Block  IUCR  \
# 646648  11044768    JA379924  8/4/2017 23:50   003XX N KARLOV AVE   320
# 646649  11043018    JA377717  8/4/2017 23:55      035XX W 16TH ST  2024
# 646650  11043092    JA377744  8/4/2017 23:55  012XX S KEDVALE AVE   560
# 646651  11043182    JA377726  8/4/2017 23:55    070XX S BISHOP ST   460
# 646652  11043059    JA377722  8/4/2017 23:59  052XX N OAKVIEW AVE  1310
#
#            Primary Type            Description     Location Description  \
# 646648          ROBBERY  STRONGARM - NO WEAPON                   STREET
# 646649        NARCOTICS    POSS: HEROIN(WHITE)                 SIDEWALK
# 646650          ASSAULT                 SIMPLE                APARTMENT
# 646651          BATTERY                 SIMPLE  RESIDENCE PORCH/HALLWAY
# 646652  CRIMINAL DAMAGE            TO PROPERTY                    OTHER
#
#        Arrest Domestic              ...                Ward  Community Area  \
# ...

# %%
df['Date'] = pd.to_datetime(df["Date"]) #df1 = df.iloc[: 500,] to load faster

# %% [markdown]
# # Date vs. Primary Type

# %%
#Finding the correlation between the dates and the frequency of the crime type,Let's focus reading the dataset based on the dates vs. the primary as this will be the main focus of the project's analysis

df_crimetype = df[["Date","Primary Type"]]

# %%
crimes_2013= df_crimetype[df_crimetype["Date"].isin(pd.date_range("2013-01-01", "2013-12-31"))]
#pd.DataFrame(pd.date_range(start='2013-01-01', end='2013-12-31', freq='D'), columns = ['Date'])
crimes_2013.tail()
# Out:
#            Date         Primary Type
# 2536 2013-12-17   DECEPTIVE PRACTICE
# 2551 2013-12-18  CRIM SEXUAL ASSAULT
# 2581 2013-12-20   DECEPTIVE PRACTICE
# 2669 2013-12-24   DECEPTIVE PRACTICE
# 2719 2013-12-27         INTIMIDATION

# %%
crimes_2013['weekday']=crimes_2013["Date"].dt.weekday
crimes_2013.head()
# Out:
# /Users/Gary/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#         Date                Primary Type  weekday
# 0 2013-01-01                 SEX OFFENSE        1
# 1 2013-01-01  OFFENSE INVOLVING CHILDREN        1
# 2 2013-01-01           HUMAN TRAFFICKING        1
# 3 2013-01-01         CRIM SEXUAL ASSAULT        1
# 4 2013-01-01          DECEPTIVE PRACTICE        1

# %% [markdown]
# # convert date format to weekday

# %%
crimecount_2013 = crimes_2013.groupby(["weekday","Primary Type"]).size()
crimecount_2013
# Out:
# weekday  Primary Type
# 0        BATTERY                        1
#          BURGLARY                       1
#          CRIM SEXUAL ASSAULT            4
#          DECEPTIVE PRACTICE            19
#          OFFENSE INVOLVING CHILDREN     6
#          OTHER OFFENSE                  1
#          SEX OFFENSE                    3
#          THEFT                          1
# 1        BATTERY                        1
#          BURGLARY                       1
#          CRIM SEXUAL ASSAULT            7
#          DECEPTIVE PRACTICE            38
#          HUMAN TRAFFICKING              1
#          MOTOR VEHICLE THEFT            2
#          OFFENSE INVOLVING CHILDREN    14
#          OTHER OFFENSE                  2
#          SEX OFFENSE                   11
#          THEFT                          3
# 2        CRIM SEXUAL ASSAULT            5
#          DECEPTIVE PRACTICE             9
#          OFFENSE INVOLVING CHILDREN     8
#          SEX OFFENSE                    2
# ...

# %%
crimelist_2013 = crimes_2013[['Primary Type','weekday']].values.tolist()
crimelist_2013
# Out:
# [['SEX OFFENSE', 1],
#  ['OFFENSE INVOLVING CHILDREN', 1],
#  ['HUMAN TRAFFICKING', 1],
#  ['CRIM SEXUAL ASSAULT', 1],
#  ['DECEPTIVE PRACTICE', 1],
#  ['SEX OFFENSE', 1],
#  ['SEX OFFENSE', 1],
#  ['OFFENSE INVOLVING CHILDREN', 1],
#  ['SEX OFFENSE', 1],
#  ['SEX OFFENSE', 1],
#  ['DECEPTIVE PRACTICE', 1],
#  ['OFFENSE INVOLVING CHILDREN', 1],
#  ['DECEPTIVE PRACTICE', 1],
#  ['DECEPTIVE PRACTICE', 1],
#  ['DECEPTIVE PRACTICE', 1],
#  ['DECEPTIVE PRACTICE', 1],
#  ['OFFENSE INVOLVING CHILDREN', 1],
#  ['DECEPTIVE PRACTICE', 1],
#  ['THEFT', 1],
#  ['OFFENSE INVOLVING CHILDREN', 1],
#  ['CRIM SEXUAL ASSAULT', 1],
#  ['OFFENSE INVOLVING CHILDREN', 1],
#  ['OFFENSE INVOLVING CHILDREN', 1],
#  ['SEX OFFENSE', 1],
#  ['DECEPTIVE PRACTICE', 1],
#  ['SEX OFFENSE', 1],
#  ['SEX OFFENSE', 1],
#  ['DECEPTIVE PRACTICE', 1],
#  ['DECEPTIVE PRACTICE', 1],
#  ['SEX OFFENSE', 1],
#  ['CRIM SEXUAL ASSAULT', 1],
#  ['CRIM SEXUAL ASSAULT', 1],
#  ['DECEPTIVE PRACTICE', 1],
#  ['SEX OFFENSE', 1],
# ...

# %% [markdown]
# # Applying Apriori algorithm on crime types for the year 2013

# %%
from apyori import apriori

results = list(apriori(crimelist_2013))
for r in results:
    print('Days: ' + str(r.items))
    print('Support: ' + str(r.support))
    print('Confidence: ' + str(r.ordered_statistics[0].confidence) + '\n')
# Out:
# Days: frozenset([0])
# Support: 0.121621621622
# Confidence: 0.121621621622
#
# Days: frozenset([1])
# Support: 0.27027027027
# Confidence: 0.27027027027
#
# Days: frozenset([3])
# Support: 0.138513513514
# Confidence: 0.138513513514
#
# Days: frozenset([4])
# Support: 0.148648648649
# Confidence: 0.148648648649
#
# Days: frozenset([5])
# Support: 0.108108108108
# Confidence: 0.108108108108
#
# Days: frozenset([6])
# Support: 0.128378378378
# Confidence: 0.128378378378
#
# Days: frozenset(['DECEPTIVE PRACTICE'])
# Support: 0.537162162162
# Confidence: 0.537162162162
#
# Days: frozenset(['OFFENSE INVOLVING CHILDREN'])
# Support: 0.168918918919
# Confidence: 0.168918918919
#
# Days: frozenset([1, 'DECEPTIVE PRACTICE'])
# Support: 0.128378378378
# Confidence: 0.475

# %% [markdown]
# # Applying Apriori algorithm on crime types for the year 2014

# %%
crimes_2014= df_crimetype[df_crimetype["Date"].isin(pd.date_range("2014-01-01", "2014-12-31"))]
crimes_2014['weekday']=crimes_2014["Date"].dt.weekday
crimelist_2014 = crimes_2014[['Primary Type','weekday']].values.tolist()
from apyori import apriori

results = list(apriori(crimelist_2014))
for r in results:
    print('Days: ' + str(r.items))
    print('Support: ' + str(r.support))
    print('Confidence: ' + str(r.ordered_statistics[0].confidence) + '\n')
# Out:
# Days: frozenset([0])
# Support: 0.171597633136
# Confidence: 0.171597633136
#
# Days: frozenset([1])
# Support: 0.130177514793
# Confidence: 0.130177514793
#
# Days: frozenset([2])
# Support: 0.236686390533
# Confidence: 0.236686390533
#
# Days: frozenset([3])
# Support: 0.121301775148
# Confidence: 0.121301775148
#
# Days: frozenset([4])
# Support: 0.112426035503
# Confidence: 0.112426035503
#
# Days: frozenset([5])
# Support: 0.12426035503
# Confidence: 0.12426035503
#
# Days: frozenset([6])
# Support: 0.103550295858
# Confidence: 0.103550295858
#
# Days: frozenset(['CRIM SEXUAL ASSAULT'])
# Support: 0.136094674556
# Confidence: 0.136094674556
#
# Days: frozenset(['DECEPTIVE PRACTICE'])
# Support: 0.420118343195
# Confidence: 0.420118343195
#
# Days: frozenset(['OFFENSE INVOLVING CHILDREN'])
# Support: 0.165680473373
# Confidence: 0.165680473373
#
# Days: frozenset(['SEX OFFENSE'])
# Support: 0.10650887574
# Confidence: 0.10650887574
# ...

# %% [markdown]
# # Applying Apriori algorithm on crime types for the year 2015

# %%
crimes_2015= df_crimetype[df_crimetype["Date"].isin(pd.date_range("2015-01-01", "2015-12-31"))]
crimes_2015['weekday']=crimes_2015["Date"].dt.weekday
crimelist_2015 = crimes_2015[['Primary Type','weekday']].values.tolist()
from apyori import apriori

results = list(apriori(crimelist_2015))
for r in results:
    print('Days: ' + str(r.items))
    print('Support: ' + str(r.support))
    print('Confidence: ' + str(r.ordered_statistics[0].confidence) + '\n')
# Out:
# Days: frozenset([0])
# Support: 0.153776978417
# Confidence: 0.153776978417
#
# Days: frozenset([1])
# Support: 0.137589928058
# Confidence: 0.137589928058
#
# Days: frozenset([2])
# Support: 0.135791366906
# Confidence: 0.135791366906
#
# Days: frozenset([3])
# Support: 0.17940647482
# Confidence: 0.17940647482
#
# Days: frozenset([4])
# Support: 0.12904676259
# Confidence: 0.12904676259
#
# Days: frozenset([5])
# Support: 0.124100719424
# Confidence: 0.124100719424
#
# Days: frozenset([6])
# Support: 0.140287769784
# Confidence: 0.140287769784
#
# Days: frozenset(['CRIMINAL DAMAGE'])
# Support: 0.122302158273
# Confidence: 0.122302158273
#
# Days: frozenset(['DECEPTIVE PRACTICE'])
# Support: 0.238309352518
# Confidence: 0.238309352518
#
# Days: frozenset(['THEFT'])
# Support: 0.219874100719
# Confidence: 0.219874100719
# /Users/Gary/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# ...

# %% [markdown]
# # Applying Apriori algorithm on crime types for the year 2016

# %%
crimes_2016= df_crimetype[df_crimetype["Date"].isin(pd.date_range("2016-01-01", "2016-12-31"))]
crimes_2016['weekday']=crimes_2016["Date"].dt.weekday
crimelist_2016 = crimes_2016[['Primary Type','weekday']].values.tolist()
from apyori import apriori

results = list(apriori(crimelist_2016))
for r in results:
    print('Days: ' + str(r.items))
    print('Support: ' + str(r.support))
    print('Confidence: ' + str(r.ordered_statistics[0].confidence) + '\n')
# Out:
# Days: frozenset([0])
# Support: 0.158396319422
# Confidence: 0.158396319422
#
# Days: frozenset([1])
# Support: 0.143608281301
# Confidence: 0.143608281301
#
# Days: frozenset([2])
# Support: 0.118632928032
# Confidence: 0.118632928032
#
# Days: frozenset([3])
# Support: 0.136378573776
# Confidence: 0.136378573776
#
# Days: frozenset([4])
# Support: 0.158396319422
# Confidence: 0.158396319422
#
# Days: frozenset([5])
# Support: 0.141307919816
# Confidence: 0.141307919816
#
# Days: frozenset([6])
# Support: 0.143279658232
# Confidence: 0.143279658232
#
# Days: frozenset(['CRIMINAL DAMAGE'])
# Support: 0.122576404864
# Confidence: 0.122576404864
#
# Days: frozenset(['DECEPTIVE PRACTICE'])
# Support: 0.234965494578
# Confidence: 0.234965494578
#
# Days: frozenset(['THEFT'])
# Support: 0.240223463687
# Confidence: 0.240223463687
# /Users/Gary/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# ...

# %% [markdown]
# # Applying Apriori algorithm on crime types for the year 2017

# %%
crimes_2017= df_crimetype[df_crimetype["Date"].isin(pd.date_range("2017-01-01", "2017-12-31"))]
crimes_2017['weekday']=crimes_2017["Date"].dt.weekday
crimelist_2017 = crimes_2017[['Primary Type','weekday']].values.tolist()
from apyori import apriori

results = list(apriori(crimelist_2017))
for r in results:
    print('Days: ' + str(r.items))
    print('Support: ' + str(r.support))
    print('Confidence: ' + str(r.ordered_statistics[0].confidence) + '\n')
# Out:
# Days: frozenset([0])
# Support: 0.143255295429
# Confidence: 0.143255295429
#
# Days: frozenset([1])
# Support: 0.135451505017
# Confidence: 0.135451505017
#
# Days: frozenset([2])
# Support: 0.135451505017
# Confidence: 0.135451505017
#
# Days: frozenset([3])
# Support: 0.122630992196
# Confidence: 0.122630992196
#
# Days: frozenset([4])
# Support: 0.125418060201
# Confidence: 0.125418060201
#
# Days: frozenset([5])
# Support: 0.154403567447
# Confidence: 0.154403567447
#
# Days: frozenset([6])
# Support: 0.183389074693
# Confidence: 0.183389074693
#
# Days: frozenset(['CRIMINAL DAMAGE'])
# Support: 0.136566332219
# Confidence: 0.136566332219
#
# Days: frozenset(['DECEPTIVE PRACTICE'])
# Support: 0.210144927536
# Confidence: 0.210144927536
#
# Days: frozenset(['THEFT'])
# Support: 0.232998885173
# Confidence: 0.232998885173
# /Users/Gary/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# ...

# %% [markdown]
# # Time vs. Crime Type
#
# convert datetime to time and time categorized to day, noon,night, late night

# %%
def time_of_day(timestamp):
    hr = timestamp.hour
    if hr>=6 and hr<12: return "daylight"
    elif hr>=12 and hr<18: return "afternoon"
    elif hr>=18 and hr<24: return "night"
    else: return "late night"

# %%
df_crimetype['time_of_day'] = df_crimetype['Date'].apply(time_of_day)
# Out:
# /Users/Gary/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_crimetype.head()
# Out:
#         Date                Primary Type time_of_day
# 0 2013-01-01                 SEX OFFENSE  late night
# 1 2013-01-01  OFFENSE INVOLVING CHILDREN  late night
# 2 2013-01-01           HUMAN TRAFFICKING  late night
# 3 2013-01-01         CRIM SEXUAL ASSAULT  late night
# 4 2013-01-01          DECEPTIVE PRACTICE  late night

# %%
df_crimetimetype = df_crimetype[['time_of_day','Primary Type']].values.tolist()#.astype(str)
df_crimetimetype[:5]
# Out:
# [['late night', 'SEX OFFENSE'],
#  ['late night', 'OFFENSE INVOLVING CHILDREN'],
#  ['late night', 'HUMAN TRAFFICKING'],
#  ['late night', 'CRIM SEXUAL ASSAULT'],
#  ['late night', 'DECEPTIVE PRACTICE']]

# %%
from apyori import apriori

results = list(apriori(df_crimetimetype ,min_support=0.05))
for r in results:
    print('Days: ' + str(r.items))
    print('Support: ' + str(r.support))
    print('Confidence: ' + str(r.ordered_statistics[0].confidence) + '\n')
# Out:
# Days: frozenset(['ASSAULT'])
# Support: 0.068876197899
# Confidence: 0.068876197899
#
# Days: frozenset(['BATTERY'])
# Support: 0.186888485788
# Confidence: 0.186888485788
#
# Days: frozenset(['BURGLARY'])
# Support: 0.0514387159729
# Confidence: 0.0514387159729
#
# Days: frozenset(['CRIMINAL DAMAGE'])
# Support: 0.112556502483
# Confidence: 0.112556502483
#
# Days: frozenset(['DECEPTIVE PRACTICE'])
# Support: 0.0677225652707
# Confidence: 0.0677225652707
#
# Days: frozenset(['NARCOTICS'])
# Support: 0.0603523064147
# Confidence: 0.0603523064147
#
# Days: frozenset(['OTHER OFFENSE'])
# Support: 0.0655529317888
# Confidence: 0.0655529317888
#
# Days: frozenset(['THEFT'])
# Support: 0.227166656615
# Confidence: 0.227166656615
#
# Days: frozenset(['afternoon'])
# Support: 0.317269076305
# Confidence: 0.317269076305
#
# Days: frozenset(['daylight'])
# Support: 0.213162236934
# Confidence: 0.213162236934
#
# Days: frozenset(['late night'])
# Support: 0.157961070311
# ...
